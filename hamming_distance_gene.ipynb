# %%
def hamming_distance(first_string, second_string):
    count=0
    for f,s in zip(first_string,second_string):
        if f != s:
            count+=1
    return count

# %%
hamming_distance("...", "...")
# Out:
# 481
