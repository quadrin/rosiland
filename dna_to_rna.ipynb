# %%
string = "..."

# %%
def split(word):
    return [char for char in word]

# %%
string_list = split(string)

# %%
for i in range(len(string_list)):
    if string_list[i] == "T":
        string_list[i] = "U"

# %%
"".join(string_list)
# Out:
# '...'
